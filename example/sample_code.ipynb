# %%
import sys
sys.path.append("../TextSimila")
from TextSimila.text_sim_reco import Text_sim_reco

# %% [markdown]
# # Example data(English ver.)

# %%
Items = [
    'what do you think about us making a house team in korea',

]
          
related_to_Items = [
    [
        's koreas next leader to abandon blue house for new office',
        'what will you find in a korean backstreet',
        'how far is tattoo far season 1 playlist',
        'kitchen',
        '41 hacks for developers marketers and agencies',
        'is korea too amazing for you to put into words',
        'best social media campaigns 2021',
        'cookin up pastas for chef dabuz',
        'space',
        'mokkiji live',
        'sportsnet',
        'youre very bad at speaking korean but its easy to say youre good',
        'alley in the house fhhh friends archdaily',
        'tweets with replies by killerton',
        'status ethstatus',
        'blood donation',
        'what do you think of this korean shrine',
        'visiting the mcdonalds in korea',
        'top 25 korean phrases'
   ],
   
]

# %% [markdown]
# ## Predict with newly-trained model

# %%
params_vid = {'lang': 'en', 'reco_Item_number': 3, 'ratio': 0.2}

params_tok = {
        'stopwords': None,
        'extranouns': None,
        'verbose': False,
        'min_noun_frequency': 1,
        'max_noun_frequency': 80,
        'max_frequency_for_char': 20,
        'min_noun_score': 0.1,
        'extract_compound': False}

params_emb = {
        'vector_size': 15, 
        'window': 3, 
        'min_count': 1, 
        'workers': 4, 
        'sg': 1}

# %%
text_sim_reco = Text_sim_reco(Items=Items,
                        related_to_Items = related_to_Items,
                        saved=True,
                        pretrain_tok=False,
                        pretrain_emb=False,
                        **params_vid,
                        **params_tok,
                        **params_emb)
text_sim_reco.train()

pred = text_sim_reco.predict()
for item, rec_item in zip(text_sim_reco.Items, pred):
    print(item)
    for idx, rec in enumerate(rec_item):
        print(f'{idx+1}: {rec}')
    print()
# Out:
# NLTK data punkt has been saved in "./model"
#
# NLTK data averaged_perceptron_tagger has been saved in "./model"
#
# The embedded_model has been saved as "embedded_model_(2).pickle" in "./model"
#
# Netflix movie
# 1: rotten tomatoes ratings
# 2: Netflix ratings
# 3: IMDb Top 250 Movie ratings
#
# Netflix party
# 1: Netflix movie
# 2: Netflix top
# 3: rotten tomatoes ratings
#
# Netflix top
# 1: Netflix party
# 2: rotten tomatoes ratings
# 3: IMDb Top 250 Movie ratings
#
# Netflix ratings
# 1: IMDb Top 250 Movie ratings
# 2: Netflix movie
# 3: rotten tomatoes ratings
#
# rotten tomatoes ratings
# 1: Netflix movie
# 2: Netflix ratings
# 3: Netflix top
#
# IMDb Top 250 Movie ratings
# 1: Netflix ratings
# 2: Netflix movie
# 3: Netflix top

# %% [markdown]
# ## Predict with Pre-trained model

# %%
params_vid = {'lang': 'en', 'reco_Item_number': 3, 'ratio': 0.2}

params_tok = {
        'stopwords': None,
        'extranouns': None,
        'verbose': False,
        'min_noun_frequency': 1,
        'max_noun_frequency': 80,
        'max_frequency_for_char': 20,
        'min_noun_score': 0.1,
        'extract_compound': False,
        # You don't need to specify the model name for tokenization while using English custom dataset
        }

params_emb = {
        'vector_size': 15, 
        'window': 3, 
        'min_count': 1, 
        'workers': 4, 
        'sg': 1,
        'model_name_emb': 'embedded_model_(2)'}

# %%
text_sim_reco = Text_sim_reco(Items=Items,
                        related_to_Items = related_to_Items,
                        pretrain_tok=True,
                        pretrain_emb=True,
                        **params_vid,
                        **params_tok,
                        **params_emb)
text_sim_reco.train()

pred = text_sim_reco.predict()
for item, rec_item in zip(text_sim_reco.Items, pred):
    print(item)
    for idx, rec in enumerate(rec_item):
        print(f'{idx+1}: {rec}')
    print()
# Out:
# NLTK data punkt has been already saved in "./model"
#
# NLTK data averaged_perceptron_tagger has been already saved in "./model"
#
# Load pre-trained model for embedding...
#
# Netflix movie
# 1: rotten tomatoes ratings
# 2: Netflix ratings
# 3: Netflix party
#
# Netflix party
# 1: Netflix movie
# 2: Netflix top
# 3: rotten tomatoes ratings
#
# Netflix top
# 1: Netflix party
# 2: rotten tomatoes ratings
# 3: Netflix ratings
#
# Netflix ratings
# 1: IMDb Top 250 Movie ratings
# 2: Netflix movie
# 3: rotten tomatoes ratings
#
# rotten tomatoes ratings
# 1: Netflix movie
# 2: Netflix ratings
# 3: Netflix top
#
# IMDb Top 250 Movie ratings
# 1: Netflix ratings
# 2: Netflix movie
# 3: rotten tomatoes ratings

# %% [markdown]
# # Example data(Korean ver.)

# %%
Items = [
    '아이유 막방',
    '아이유 앵콜',
    '아이유 공연',
    '아이유 기타',
    '기타로 연주',
    '초보자를 위한 기타 레슨'
]

related_to_Items = [
    ['막방 공연','아이유'],
    ['앵콜 실수','아이유'],
    ['공연 콘서트 정보','아이유'],
    ['기타'],
    ['연주'],
    ['기타']
    ]

# %% [markdown]
# ## Predict with newly-trained model

# %%
params_vid = {'lang': 'ko', 'reco_Item_number': 3, 'ratio': 0.2}

params_tok = {
        'stopwords': None,
        'extranouns': None,
        'verbose': False,
        'min_noun_frequency': 1,
        'max_noun_frequency': 80,
        'max_frequency_for_char': 20,
        'min_noun_score': 0.1,
        'extract_compound': False}
        
params_emb = {
        'vector_size': 15, 
        'window': 3, 
        'min_count': 1, 
        'workers': 4, 
        'sg': 1}

# %%
text_sim_reco = Text_sim_reco(Items=Items,
        related_to_Items = related_to_Items,
        saved=True,
        pretrain_tok=False,
        pretrain_emb=False,
        **params_vid,
        **params_tok,
        **params_emb)
text_sim_reco.train()

pred = text_sim_reco.predict()
for item, rec_item in zip(text_sim_reco.Items, pred):
    print(item)
    for idx, rec in enumerate(rec_item):
        print(f'{idx+1}: {rec}')
    print()
# Out:
# The tokenized_nouns has been saved as "tokenized_nouns.pickle" in "./model"
#
# The embedded_model has been saved as "embedded_model.pickle" in "./model"
#
# 아이유 막방
# 1: 아이유 앵콜
# 2: 아이유 공연
# 3: 아이유 기타
#
# 아이유 앵콜
# 1: 아이유 공연
# 2: 아이유 막방
# 3: 아이유 기타
#
# 아이유 공연
# 1: 아이유 앵콜
# 2: 아이유 막방
# 3: 아이유 기타
#
# 아이유 기타
# 1: 기타로 연주
# 2: 초보자를 위한 기타 레슨
# 3: 아이유 막방
#
# 기타로 연주
# 1: 아이유 기타
# 2: 초보자를 위한 기타 레슨
# 3: 아이유 막방
#
# 초보자를 위한 기타 레슨
# 1: 아이유 기타
# 2: 기타로 연주
# 3: 아이유 막방

# %% [markdown]
# ## Predict with Pre-trained model

# %%
params_vid = {'lang': 'ko', 'reco_Item_number': 3, 'ratio': 0.2}

params_tok = {
        'stopwords': None,
        'extranouns': None,
        'verbose': False,
        'min_noun_frequency': 1,
        'max_noun_frequency': 80,
        'max_frequency_for_char': 20,
        'min_noun_score': 0.1,
        'extract_compound': False,
        'model_name_tok': 'tokenized_nouns'}

params_emb = {
        'vector_size': 15, 
        'window': 3, 
        'min_count': 1, 
        'workers': 4, 
        'sg': 1,
        'model_name_emb': 'embedded_model'}

# %%
text_sim_reco = Text_sim_reco(Items=Items,
                        related_to_Items = related_to_Items,
                        pretrain_tok=True,
                        pretrain_emb=True,
                        **params_vid,
                        **params_tok,
                        **params_emb)
text_sim_reco.train()

pred = text_sim_reco.predict()
for item, rec_item in zip(text_sim_reco.Items, pred):
    print(item)
    for idx, rec in enumerate(rec_item):
        print(f'{idx+1}: {rec}')
    print()
# Out:
# Load pre-trained model for tokenization...
#
# Load pre-trained model for embedding...
#
# 아이유 막방
# 1: 아이유 공연
# 2: 아이유 앵콜
# 3: 아이유 기타
#
# 아이유 앵콜
# 1: 아이유 공연
# 2: 아이유 막방
# 3: 아이유 기타
#
# 아이유 공연
# 1: 아이유 앵콜
# 2: 아이유 막방
# 3: 아이유 기타
#
# 아이유 기타
# 1: 기타로 연주
# 2: 초보자를 위한 기타 레슨
# 3: 아이유 앵콜
#
# 기타로 연주
# 1: 아이유 기타
# 2: 초보자를 위한 기타 레슨
# 3: 아이유 앵콜
#
# 초보자를 위한 기타 레슨
# 1: 아이유 기타
# 2: 기타로 연주
# 3: 아이유 앵콜
